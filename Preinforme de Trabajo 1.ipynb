# %% [markdown]
# # **Preinforme de trabajo #1**
# 23/02/2023
#
# ## Integrantes:
# *   Juan José Cortés Fajardo - Correo
# *   Samuel Velazques - Correo
# *   Josué Paniagua - Correo

# %% [markdown]
# ## **Punto N-1**
#
# Enunciado propuesto
#
# **Solución:**
#
# En este espacio se escribe la solución

# %%
#Espacio para escribir código en caso de ser solicitado

# %% [markdown]
# ## **Punto N**
#
# Enunciado propuesto
#
# **Solución:**
#
# En este espacio se escribe la solución

# %%
#Espacio para escribir código en caso de ser solicitado
